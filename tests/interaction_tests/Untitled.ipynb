# %%
# %matplotlib inline

# %%
import scipy as S
import numpy as np

# %%
import gemstat.matrix as GSMAT

# %%
x = np.linspace(0.0,1.0,100)

gradient_1 = np.linspace(1.0,0.0,100)
gradient_2 = np.linspace(0.0,1.0,100)

inputs = GSMAT.GEMSTAT_Matrix()
inputs.add_row("first",gradient_1)
inputs.add_row("second",gradient_2)

inputs.write("./factor_expr.tab")

# %%
def hill_function(concentration, half_at=0.5,coop=1.0):
    return S.power(S.power(half_at/concentration,coop)+1.0,-1.0)

# %%
import pylab
pylab.plot(hill_function(gradient_1,0.5,1.0) )
pylab.ylim(0.0,1.0)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in divide
#   from ipykernel import kernelapp as app
# (0.0, 1.0)

# %%
a = hill_function(gradient_1,0.5,1.0)
b = 2.0*hill_function(gradient_1,0.5,1.0)
c = b
d = b

expr_1 = GSMAT.GEMSTAT_Matrix()
expr_1.add_row("a",hill_function(gradient_1,0.5,1.0))
expr_1.add_row("b",2.0*hill_function(gradient_1,0.5,1.0))
expr_1.add_row("c",2.0*hill_function(gradient_1,0.5,1.0))
expr_1.add_row("d",2.0*hill_function(gradient_1,0.5,1.0))
expr_1.write("./expr.1")
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in divide
#   from ipykernel import kernelapp as app

# %%
o1 = GSMAT.GEMSTAT_Matrix.load("out.4")
fig = pylab.figure(figsize=(15,8))

for n in o1.names[-4:]:
    pylab.plot(o1[str(n)][0]+0.01*S.randn(100),label=n)
    
pylab.legend()
#pylab.ylim(0.0,2.0)

# %%
o1.names
# Out:
# array([u'a', u'b', u'c', u'd'],
#       dtype='<U1')

# %%
o1["a"]
# Out:
# array([[ 3.75   ,  3.74682,  3.74359,  3.74031,  3.73698,  3.73359,
#          3.73016,  3.72667,  3.72312,  3.71951,  3.71585,  3.71212,
#          3.70833,  3.70448,  3.70057,  3.69658,  3.69253,  3.6884 ,
#          3.68421,  3.67994,  3.6756 ,  3.67117,  3.66667,  3.66208,
#          3.65741,  3.65265,  3.6478 ,  3.64286,  3.63782,  3.63269,
#          3.62745,  3.62211,  3.61667,  3.61111,  3.60544,  3.59965,
#          3.59375,  3.58772,  3.58156,  3.57527,  3.56884,  3.56227,
#          3.55556,  3.54869,  3.54167,  3.53448,  3.52713,  3.51961,
#          3.5119 ,  3.50402,  3.49594,  3.48766,  3.47917,  3.47047,
#          3.46154,  3.45238,  3.44298,  3.43333,  3.42342,  3.41324,
#          3.40278,  3.39202,  3.38096,  3.36957,  3.35785,  3.34577,
#          3.33333,  3.32051,  3.30729,  3.29365,  3.27957,  3.26503,
#          3.25   ,  3.23447,  3.2184 ,  3.20175,  3.18452,  3.16666,
#          3.14815,  3.12893,  3.10898,  3.08824,  3.06667,  3.04423,
# ...
